# %% [markdown]
# công việc train kmean bắt đầu
# input : dataset của  tiếng  việt

# %%
# %cd fairseq/
# Out:
# /home/khanh/Projects/KhoaLuan/fairseq

# %%
#  bước đầu tiên trích xuất đặc chưng của tiếng viếng việt đầu râ cua file này là 1 .len và file .npy 
#  input đầu vào là 1 file train.tsv của tiếng việt chứa địa chỉ của nó

# %%
#  sử dụng wav2vec_manifest.py để tạo file train.tsv (cần tạo 2 file cho valid và train )
# !python examples/wav2vec/wav2vec_manifest.py ../my_data/source_wav_16k/valid --dest ../test_manifesr/valid --ext wav --valid-percent 0
# !mv ../test_manifesr/valid/train.tsv ../test_manifesr/valid/valid.tsv
#  file train 
# !python examples/wav2vec/wav2vec_manifest.py ../my_data/source_wav_16k/train --dest ../test_manifesr/train --ext wav --valid-percent 0
